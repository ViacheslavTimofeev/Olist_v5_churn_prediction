# %% [markdown]
# # Информация о продавцах (sellers_olist_public_dataset_.csv)

# %%
import pandas as pd

# %%
sellers = pd.read_csv(r'C:\Users\Вячеслав\Documents\olist_churn\olist-ml-churn-prediction\data\raw\sellers_olist_public_dataset_.csv')

# %%
display(sellers.head())
print(sellers.shape)
# Out:
#                            order_id                        product_id  \
# 0  0faabac07131235fc5d9d711471cb4db  40b09f33e646d488df2ca6fec4082d50
# 1  970f41d57d6e21afa7b8c701b09acb95  d1c427060a0f73f6b889a5c7c61f2ac4
# 2  b674ed44cc3f6a869249421debebe104  bd7cd34fc6d02e730221b11edc354aae
# 3  cbe9eae36605cf2bd005c6bc1ae5f864  0e95d6eef2bedaf4ecf3c33f78199059
# 4  f562f8a4adf5a459176f7170d0da220d  9a3a44b7cc16f2592b2110e4205edf97
#
#                           seller_id  seller_zip_code_prefix  \
# 0  3d871de0142ce09b7081e2b9d1733cb1                     132
# 1  a1043bafd471dff536d0c462352beb48                     371
# 2  46dc3b2cc0980fb8ec44634e21d2718e                     222
# 3  dc4a0fc896dc34b0d5bfec8438291c80                     149
# 4  5a8e7d5003a1f221f9e1d6e411de7c23                     130
#
#             seller_city seller_state
# 0  campo limpo paulista           SP
# 1              ilicinea           MG
# 2        rio de janeiro           RJ
# 3              ibitinga           SP
# 4              campinas           SP
# (98981, 6)

# %%
for col in sellers.columns:
    print(f"--- {col} ---")
    print(sellers[col].value_counts())
    print()
# Out:
# --- order_id ---
# order_id
# f04396b769e9563e83456389c7d8f043    8
# 7d8f5bfd5aff648220374a2df62e84d5    6
# 5a3b1c29a49756e75f1ef513383c0c12    6
# d281ffe6e49a2a896db2eb9febfe07f8    6
# 3990f96693d321ac142fff312bf3706a    6
#                                    ..
# 3b49e8b3142b569c258368484a58bcea    1
# 2e0f7705cce568d0fe13d933d7165c79    1
# fd1d8203059d4371690b543f376f5bbc    1
# 06d7e8a85f5cfef576c5303ed7d7f2e5    1
# d65ec1b28617b16c0747b22c49a979a6    1
# Name: count, Length: 96247, dtype: int64
#
# --- product_id ---
# product_id
# 99a4788cb24856965c36a24e339b6058    648
# aca2eb7d00ea1a7b8ebd4e68314663af    615
# 422879e10f46682990de24d770e7f83d    472
# d1c427060a0f73f6b889a5c7c61f2ac4    449
# 389d119b48cf3043d311335e499d9c6b    433
#                                    ...
# 57da0b2b326cf3060764f4a34299c1a2      1
# dc5810c618a462436499ac6e62aeddc3      1
# 715959a7c12fbcea5d545e6aa7f46178      1
# bba0d9c4f470ff541dba7f02d791a4f3      1
# f0978bc4bcd57a1f2079015178b73cad      1
# Name: count, Length: 24440, dtype: int64
#
# --- seller_id ---
# seller_id
# 6560211a19b47992c3666cc44a7e94c0    2906
# 4a3ca9315b744ce9f8e9374361493884    2616
# cc419e0650a3c5ba77189a1882b7556a    2322
# da8622b14eb17ae2831f4ac5b9dab84a    2019
# 1f50f920176fa81dab994f9023523100    2012
#                                     ...
# a75ff3716d1f5c1edf2ce260d586a5d3       1
# 62d712b0cb9e20ce3589f485674579e7       1
# 34675b28b826facfde119785bf287dc1       1
# feaaac1c3e59e8f657ba338de1a83a6b       1
# 18e694e0e48ed6f7aa3f24aade5fd697       1
# Name: count, Length: 2104, dtype: int64
#
# --- seller_zip_code_prefix ---
# seller_zip_code_prefix
# 149    7611
# 134    3896
# 58     2941
# 150    2687
# 132    2517
#        ...
# 835       1
# 242       1
# 336       1
# 307       1
# 896       1
# Name: count, Length: 427, dtype: int64
#
# --- seller_city ---
# seller_city
# sao paulo          22669
# ibitinga            7585
# santo andre         3285
# curitiba            2757
# belo horizonte      2632
#                    ...
# sao bento              1
# olinda                 1
# jandira                1
# bom jardim             1
# varzea paulista        1
# Name: count, Length: 476, dtype: int64
#
# --- seller_state ---
# seller_state
# SP    70721
# MG     9072
# PR     7589
# SC     3537
# RJ     3494
# RS     1949
# DF      785
# BA      545
# GO      431
# ES      309
# MT      154
# PE      111
# RN       77
# CE       69
# MS       46
# PB       29
# RO       18
# PI       17
# PA       12
# SE        7
# AM        5
# sp        4
# Name: count, dtype: int64

# %% [markdown]
# ## Выводы из таблицы sellers:
# 1. Местоположение большинства продавцов - город sao paulo штата SP.
# 2. Есть как продавцы с большим количеством выставленных товаров (более 1000 лотов) так и продавцы с единственным товаром.
